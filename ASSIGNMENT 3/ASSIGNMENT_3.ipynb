# %%
#NUMBER GUESSING GAME

import random  # import the random module to generate random numbers

secret_number = random.randint(1,10)  # picks a random number between 1 and 10 (including 1 and 10)
attempts = 3  # user gets only 3 tries to guess the number correctly

while attempts > 0:  # keep looping as long as the attempts remain < 3
    guess = int(input("Guess the number (between 1 and 10): "))  # take user's guess as input and stores as int

    if guess < 1 or guess > 10:  # check if the guess is outside the valid range
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue  # skip the rest of this loop (doesn't count as an attempt used)

    attempts -= 1  #if valid guess, it uses up one attempt.

    if guess > secret_number:  # guess is higher than the secret number
        print("Too high. Try again.")
    elif guess < secret_number:  # guess is lower than the secret number
        print("Too low. Try again.")
    else:  # guess matches the secret number
        print("Congratulations! You guessed the correct number.")
        break  # exit the while loop immediately since the game is won. This line breaks the whole loop as the game is over.
else:

# %% [markdown]
# this 'else' belongs to the while loop, not an if statement
# it runs only if the loop finished normally (attempts ran out) without hitting 'break'

# %%
    print("Better luck next time! The number was", secret_number)

#MULTIPLICATION TABLE GENERATOR

number=int(input("ENTER THE NUMBER FOR ITS MULTIPLICATION TABLE :"))# take input as text, convert to integer, store in 'number'
for i in range(1,11): #range from 1 to 11 gives access to number including 1 and excluding 11. so the range is set from 1 to 11
    print(number,"x",i,"=",number*i) #prints the line "number from the user input" x "range value" = "user input multiplied by the range value"


#BMI CALCULATOR

def calculate_bmi(weight, height):  # define a function that takes weight and height as parameters
    bmi = weight / (height ** 2)  # BMI formula: weight divided by height squared
    return bmi  # send the calculated BMI value back to wherever the function was called

weight = float(input("Enter your weight in kg: "))  # get weight as a decimal number
height = float(input("Enter your height in meters: "))  # get height as a decimal number

bmi_result = calculate_bmi(weight, height)  # call the function, passing in weight and height
print(f"Your BMI is: {bmi_result:.2f}")# print result rounded to 2 decimal places using :.2f format
